# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"D:\DataScience\Datascience Assignment\03 sales_data_with_discounts.csv")

# %%
df.head()
# Out:
#          Date       Day  SKU City  Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C      15  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C      10  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C       7  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C       6  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C       3  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      12100             181500          11.654820     21153.498820
# 1      10100             101000          11.560498     11676.102961
# 2      16100             112700           9.456886     10657.910157
# 3      20100             120600           6.935385      8364.074702
# 4       8100              24300          17.995663      4372.946230
#
#    Net Sales Value
# 0    160346.501180
# 1     89323.897039
# 2    102042.089843
# 3    112235.925298
# 4     19927.053770

# %%
# Numerical columns
num_cols = df.select_dtypes(include = ["int64","float64"]).columns
num_cols
# Out:
# Index(['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %%
# categorical column
cat_cols = df.select_dtypes(include = ["object"]).columns
cat_cols
# Out:
# Index(['Date', 'Day', 'SKU', 'City', 'BU', 'Brand', 'Model'], dtype='object')

# %%
# mean , median , mode , standard deviation
stats = pd.DataFrame({
    "Mean": df[num_cols].mean(),
    "Median":  df[num_cols].median(),
    "Mode": df[num_cols].mode().iloc[0],
    "Standard Deviation": df[num_cols].std()
})

# %%
stats
# Out:
#                            Mean       Median          Mode  Standard Deviation
# Volume                 5.066667     4.000000      3.000000            4.231602
# Avg Price          10453.433333  1450.000000    400.000000        18079.904840
# Total Sales Value  33812.835556  5700.000000  24300.000000        50535.074173
# Discount Rate (%)     15.155242    16.577766      5.007822            4.220602
# Discount Amount     3346.499424   988.933733     69.177942         4509.902963
# Net Sales Value    30466.336131  4677.788059    326.974801        46358.656624

# %%
# Data visualization

# %%
# A . Histograms (Distribution of Numerical Data)

# %%
df[num_cols].hist(figsize=(12 , 8), bins=20)
plt.suptitle("Histograms of Numerical Columns")
plt.show()

# %%
# B.  Box Plot(Outlier Detection)

# %%
plt.figure(figsize = (12 ,6))
sns.boxplot(data = df[num_cols])
plt.title("Boxplot of Numerical Columns")
plt.show()

# %%
# C. Bar Chart for Categorical columns

# %%
for col in cat_cols:
    plt.figure(figsize=(6, 4))
    df[col].value_counts().plot(kind="bar")
    plt.title(f"Bar Chart of {col}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.show()

# %%
# 5 .Data Preprocessing 
# Handing Missing values

# %%
#df.insnull().sim()

# %%
# fill numerical missing values with mean
df[num_cols] = df[num_cols].fillna(df[num_cols].mean())

# %%
# Remove Duplicate Rows

# %%
df = df.drop_duplicates()

# %%
"""
6. Conclusion
In this analysis, descriptive statistics such as mean, median, mode, and standard deviation were calculated to understand the distribution of numerical variables.
Histograms and boxplots revealed skewness and the presence of outliers in sales and discount values.
Bar charts provided insights into categorical data distribution.
Data preprocessing steps like handling missing values and removing duplicates improved data quality for further analysis.
"""
# Out:
# '\n6. Conclusion\nIn this analysis, descriptive statistics such as mean, median, mode, and standard deviation were calculated to understand the distribution of numerical variables.\nHistograms and boxplots revealed skewness and the presence of outliers in sales and discount values.\nBar charts provided insights into categorical data distribution.\nData preprocessing steps like handling missing values and removing duplicates improved data quality for further analysis.\n'
